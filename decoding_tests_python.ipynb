# %%
#pip install mat73 (to read matlab v7.3 .mat)
#pip install nose
# Out:
# Collecting mat73
#   Downloading mat73-0.59-py3-none-any.whl (19 kB)
# Requirement already satisfied: h5py in /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages (from mat73) (3.7.0)
# Requirement already satisfied: numpy in /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages (from mat73) (1.21.6)
# Installing collected packages: mat73
# Successfully installed mat73-0.59
# Note: you may need to restart the kernel to use updated packages.

# %%
from scipy.io import loadmat
import numpy as np
import pandas as pd
import mat73

# %%
import matplotlib.pyplot as plt

# %%
from base_stats import corr_linear_circular

# %%
path = '/Users/alex/Library/CloudStorage/OneDrive-UniversitatdeBarcelona/TOOLBOXES/decoding-toolbox/data/'

# %%
path_ori_data = path + 'testdata_orientation.mat'

# %%
ori_data = mat73.loadmat(path_ori_data)

# %%
Y = ori_data['X']
Y = np.deg2rad(Y * (180/8))
X = ori_data['Y']
# reordering
X = np.einsum('kji->ikj', X)

# %%
X.shape
# Out:
# (760, 273, 211)

# %%
n_trial, n_chan, n_time = X.shape

# %%
Xreshape = X.reshape([-1, n_chan * n_time])

# %%
# linear circular correlation between MEG and stim angle
_, R2, _ = corr_linear_circular(Xreshape, Y)

# plot the effect size using MNE
R2 = R2.reshape([n_chan, n_time])

# %%
plt.plot(np.squeeze(np.mean(R2,0)))

# %%
plt.plot(R)

# %%
plt.imshow(R2)

# %%
# %matplotlib inline
import pickle
import matplotlib.pyplot as plt
import numpy as np

from mne import read_epochs
from mne.decoding import SlidingEstimator,GeneralizingEstimator

from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score
from sklearn.svm import LinearSVR

#from jr.gat import subscore
#from jr.gat import AngularRegression, scorer_angle
#from jr.stats import corr_linear_circular
#from jr.plot import pretty_gat, pretty_decod

# %%
import sys
#print(sys.path)

# %%
path_utils = '/Users/alex/Library/CloudStorage/OneDrive-UniversitatdeBarcelona/Projects/Condcision/Group_level_analyses/Beh_analyses/EEG_condcision_CJ/helper_funcs' 
sys.path.append(path_utils)

# %%
import classifier_funcs

# %%
from classifier_funcs import AngularRegression, scorer_angle

# %%
clf_angle = make_pipeline(StandardScaler(), AngularRegression(clf=LinearSVR()))

# %%
clf_angle
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('angularregression', AngularRegression(clf=LinearSVR()))])

# %%
clf_angle = make_pipeline(StandardScaler(), AngularRegression(clf=LinearSVR()))
td = SlidingEstimator(clf=clf_angle, scorer=scorer_angle, n_jobs=-1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_7114/1163102615.py in <module>
#       1 clf_angle = make_pipeline(StandardScaler(), AngularRegression(clf=LinearSVR()))
# ----> 2 td = SlidingEstimator(clf=clf_angle, scorer=scorer_angle, n_jobs=-1)
#
# TypeError: __init__() got an unexpected keyword argument 'clf'

# %%
td = SlidingEstimator(clf_angle,n_jobs=1)

# %%
td = SlidingEstimator(clf_angle,n_jobs=1)

# %%
X.shape
# Out:
# (760, 57603)

# %%
preds = td.predict(X = X)
# Out:
#   0%|          | Transforming SlidingEstimator : 0/211 [00:00<?,       ?it/s]

# %%
np.rad2deg(preds).shape
# Out:
# (760, 211)

# %%
Y
# Out:
# array([2.74889357, 0.        , 2.35619449, 2.74889357, 0.        ,
#        0.        , 0.        , 0.78539816, 1.96349541, 1.57079633,
#        0.        , 0.78539816, 1.96349541, 0.39269908, 2.35619449,
#        1.96349541, 1.57079633, 2.74889357, 0.39269908, 1.17809725,
#        1.96349541, 2.35619449, 0.        , 1.17809725, 0.39269908,
#        1.57079633, 1.57079633, 1.57079633, 1.96349541, 0.        ,
#        0.78539816, 0.78539816, 0.39269908, 1.17809725, 1.96349541,
#        1.17809725, 1.17809725, 1.17809725, 0.39269908, 1.57079633,
#        0.39269908, 1.17809725, 2.35619449, 0.39269908, 2.74889357,
#        0.39269908, 2.35619449, 1.57079633, 0.        , 0.        ,
#        0.78539816, 0.39269908, 1.96349541, 2.74889357, 0.39269908,
#        1.17809725, 1.96349541, 0.        , 0.39269908, 2.35619449,
#        1.17809725, 0.78539816, 0.78539816, 0.39269908, 1.17809725,
#        1.57079633, 2.35619449, 2.74889357, 1.57079633, 0.39269908,
#        0.39269908, 2.35619449, 2.35619449, 0.78539816, 2.35619449,
#        1.96349541, 2.35619449, 1.96349541, 0.78539816, 0.39269908,
#        0.        , 1.96349541, 1.17809725, 1.57079633, 1.96349541,
#        2.74889357, 2.74889357, 2.74889357, 0.        , 2.74889357,
#        0.39269908, 1.96349541, 1.17809725, 2.74889357, 1.57079633,
#        1.96349541, 1.17809725, 1.57079633, 0.        , 1.57079633,
#        2.35619449, 2.74889357, 1.17809725, 0.        , 0.78539816,
#        0.39269908, 0.39269908, 0.78539816, 0.78539816, 2.74889357,
#        2.35619449, 0.        , 2.35619449, 1.57079633, 1.17809725,
#        1.96349541, 0.78539816, 1.96349541, 1.17809725, 0.39269908,
#        1.57079633, 1.96349541, 1.96349541, 0.78539816, 1.57079633,
#        1.57079633, 0.78539816, 0.        , 1.57079633, 1.17809725,
#        1.57079633, 0.78539816, 2.74889357, 2.35619449, 0.39269908,
#        0.        , 2.74889357, 0.        , 1.96349541, 0.78539816,
#        1.17809725, 2.35619449, 0.        , 0.        , 2.35619449,
#        2.74889357, 1.17809725, 0.39269908, 2.74889357, 0.        ])

# %%
 np.corrcoef(Y,preds[:,100])[0,1]
# Out:
# 0.5193997986493272

# %%
R = np.array([])

# %%
scorer_angle(Y,preds[:,col])
# Out:
# 1.0204961426392614

# %%
plt.plot(scorer_angle(Y,preds)-1)

# %%
plt.plot(scorer_angle(Y,preds)-1)

# %%
R = np.array([])
for col in range(preds.shape[1]):
    R = np.append(R,R_val)

# %%
td.score
# Out:
# <bound method SlidingEstimator.score of <SlidingEstimator(base_estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('angularregression', AngularRegression(clf=LinearSVR()))]),
#          n_jobs=1, scoring=<function scorer_angle at 0x7f9a2099aef0>, fitted with 211 estimators>>

# %%
plt.plot(R)

# %%
for i in np.range(0,760)
    print(i)
# Out:
#   File "/var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_7114/3810183882.py", line 1
#     for i in np.range(0,760)
#                             ^
# SyntaxError: invalid syntax

# %%
60*4/5
# Out:
# 48.0

# %%
scorer_angle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_7114/2707103881.py in <module>
# ----> 1 scorer_angle()
#
# TypeError: scorer_angle() missing 2 required positional arguments: 'y_true' and 'y_pred'

# %%
preds.shape
# Out:
# (760, 211)

# %%
np.rad2deg(preds)
# Out:
# array([[  42.85065189,   39.91441692,  -77.79504565, ...,  -20.40300917,
#          -44.08947557,  -57.41723134],
#        [  29.05278414,   11.42740735,    5.87229298, ...,  -96.5407536 ,
#           14.84215603,   75.69212339],
#        [  -7.65707702,  -16.54488895, -159.87694988, ...,  -91.6471407 ,
#          -60.74211829,  -97.5266647 ],
#        ...,
#        [   6.09244753,  -51.04984565,  -15.66700888, ...,   57.58403176,
#           24.31958012,   10.80545825],
#        [ -24.13673591,   44.96281393,   32.57563907, ...,   38.49615496,
#           17.49664117,   19.28901272],
#        [   2.19252334,  -19.07374926,   -2.71690556, ...,  -11.19091062,
#           32.46044491,   54.18956124]])

# %%
td.fit(X = X, y = Y)
# Out:
#   0%|          | Fitting SlidingEstimator : 0/211 [00:00<?,       ?it/s]
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# ...
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# /Users/alex/opt/anaconda3/envs/mne/lib/python3.7/site-packages/sklearn/svm/_base.py:1208: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   ConvergenceWarning,
# <SlidingEstimator(base_estimator=Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('angularregression', AngularRegression(clf=LinearSVR()))]),
#          n_jobs=1, scoring=None, fitted with 211 estimators>

# %%
t

# %%
td.score(X = X, y = Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_7114/492840511.py in <module>
# ----> 1 td.score()
#
# TypeError: score() missing 2 required positional arguments: 'X' and 'y'

# %%
plt.plot(td.score(X=X, y=Y))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_7114/4136529421.py in <module>
# ----> 1 plt.plot(td.score(X=X, y=Y))
#
# ~/opt/anaconda3/envs/mne/lib/python3.7/site-packages/mne/decoding/search_light.py in score(self, X, y)
#     280         est_splits = np.array_split(self.estimators_, n_jobs)
#     281         score = parallel(p_func(est, scoring, x, y)
# --> 282                          for (est, x) in zip(est_splits, X_splits))
#     283
#     284         score = np.concatenate(score, axis=0)
#
# ~/opt/anaconda3/envs/mne/lib/python3.7/site-packages/mne/decoding/search_light.py in <genexpr>(.0)
#     280         est_splits = np.array_split(self.estimators_, n_jobs)
#     281         score = parallel(p_func(est, scoring, x, y)
# --> 282                          for (est, x) in zip(est_splits, X_splits))
#     283
#     284         score = np.concatenate(score, axis=0)
#
# ~/opt/anaconda3/envs/mne/lib/python3.7/site-packages/mne/decoding/search_light.py in _sl_score(estimators, scoring, X, y)
#     391     score = np.zeros(n_tasks)
#     392     for ii, est in enumerate(estimators):
# --> 393         score[ii] = scoring(est, X[..., ii], y)
#     394     return score
#     395
#
# ~/Library/CloudStorage/OneDrive-UniversitatdeBarcelona/Projects/Condcision/Group_level_analyses/Beh_analyses/EEG_condcision_CJ/helper_funcs/scorers.py in scorer_angle(y_true, y_pred, n_jobs)
#      84 def scorer_angle(y_true, y_pred, n_jobs=1):
#      85     """Scoring function dedicated to AngularRegressor"""
# ---> 86     y_true, y_pred, shape = _check_y(y_true, y_pred)
#      87     accuracy = _parallel_scorer(y_true, y_pred, _angle_accuracy, n_jobs)
#      88     if (len(shape) > 1) and (np.sum(shape[1:]) > 1):
#
# ~/Library/CloudStorage/OneDrive-UniversitatdeBarcelona/Projects/Condcision/Group_level_analyses/Beh_analyses/EEG_condcision_CJ/helper_funcs/scorers.py in _check_y(y_true, y_pred)
#      33     assert_true(y_true.ndim == 1)
#      34     # remove nan values XXX non-adjacency need memory!
# ---> 35     if np.any(np.isnan(y_true)) or np.any(np.isnan(y_pred)):
#      36         sel = np.where(~np.isnan(y_true[:, np.newaxis] + y_pred))[0]
#      37         y_true = y_true[sel]
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
Y
# Out:
# array([7., 0., 6., 7., 0., 4., 1., 0., 1., 3., 3., 3., 3., 5., 6., 0., 2.,
#        3., 5., 1., 7., 2., 5., 1., 0., 7., 4., 5., 0., 3., 3., 6., 5., 2.,
#        6., 6., 6., 0., 5., 4., 4., 1., 7., 4., 3., 7., 4., 0., 6., 1., 1.,
#        4., 2., 4., 4., 5., 0., 3., 5., 6., 5., 3., 4., 2., 7., 2., 7., 2.,
#        2., 6., 6., 2., 1., 6., 0., 2., 1., 7., 1., 0., 6., 7., 0., 7., 7.,
#        5., 1., 2., 5., 4., 4., 1., 3., 2., 6., 5., 1., 4., 7., 4., 7., 0.,
#        5., 1., 4., 2., 5., 0., 6., 2., 0., 0., 0., 7., 6., 5., 5., 2., 3.,
#        5., 2., 2., 0., 5., 2., 3., 1., 3., 1., 6., 4., 4., 0., 3., 2., 2.,
#        6., 3., 2., 7., 7., 0., 5., 4., 6., 1., 4., 7., 6., 7., 0., 0., 7.,
#        3., 2., 7., 5., 2., 3., 7., 2., 1., 5., 0., 1., 5., 1., 7., 6., 7.,
#        3., 6., 3., 3., 3., 1., 0., 4., 4., 5., 1., 4., 6., 4., 4., 1., 6.,
#        6., 0., 4., 0., 4., 7., 7., 3., 6., 5., 5., 3., 2., 1., 1., 3., 5.,
#        6., 4., 4., 1., 1., 2., 5., 3., 0., 2., 4., 4., 6., 6., 5., 6., 7.,
#        3., 7., 3., 0., 1., 5., 0., 4., 0., 0., 1., 2., 7., 3., 2., 7., 3.,
#        1., 5., 2., 2., 6., 6., 1., 0., 2., 5., 3., 1., 6., 4., 3., 3., 2.,
#        2., 5., 7., 4., 2., 7., 6., 5., 1., 0., 5., 1., 3., 6., 6., 7., 4.,
#        4., 6., 4., 0., 5., 7., 0., 7., 1., 5., 7., 2., 6., 5., 2., 1., 3.,
#        0., 6., 6., 6., 0., 7., 0., 5., 3., 4., 5., 6., 5., 6., 7., 5., 7.,
#        7., 1., 5., 3., 4., 2., 1., 4., 5., 6., 3., 7., 0., 3., 1., 5., 6.,
#        3., 7., 6., 7., 4., 3., 0., 0., 2., 2., 4., 4., 0., 4., 0., 6., 5.,
#        2., 2., 4., 5., 0., 2., 2., 1., 2., 1., 6., 7., 2., 1., 1., 4., 0.,

# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_7114/2907008908.py in <module>
#       1 # Plot the scores
# ----> 2 td.plot(chance=0.)
#
# AttributeError: 'SlidingEstimator' object has no attribute 'plot'

# %%
# Let's use a double regressor to estimate the angle from the sine and cosine
# See `method_model_types.ipynb` to see understand how this is built.

#/!\ On the server, there's only one core, so be patient!

clf_angle = make_pipeline(StandardScaler(), AngularRegression(clf=LinearSVR()))
td = TimeDecoding(clf=clf_angle, scorer=scorer_angle, n_jobs=-1)

# Define regressor
y = np.array(events['probe_circAngle'].values)

# This can take a while, so let's only decode around probe onset
epochs_probe = epochs.crop(.700, copy=True)

# Fit models with cross validation
td.fit(epochs_probe, y=y)

# Predict orientation and score the difference between true and predicted
# orientations
td.score(epochs_probe, y=y)

# Plot the scores
td.plot(chance=0.)
plt.show()

# %%
R2.shape
# Out:
# (273, 211)

# %%
n_trial, n_chan, n_time = X.shape

# %%
n_trial
# Out:
# 273

# %%
corr_linear_circular
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_4877/612042676.py in <module>
# ----> 1 corr_linear_circular
#
# NameError: name 'corr_linear_circular' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_4877/2387411950.py in <module>
# ----> 1 reload( base_stats)
#
# ~/opt/anaconda3/envs/mne/lib/python3.7/importlib/__init__.py in reload(module)
#     167         if spec is None:
#     168             raise ModuleNotFoundError(f"spec not found for the module {name!r}", name=name)
# --> 169         _bootstrap._exec(spec, module)
#     170         # The module may have replaced itself in sys.modules!
#     171         return sys.modules[name]
#
# ~/opt/anaconda3/envs/mne/lib/python3.7/importlib/_bootstrap.py in _exec(spec, module)
#
# ~/opt/anaconda3/envs/mne/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/opt/anaconda3/envs/mne/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/Library/CloudStorage/OneDrive-UniversitatdeBarcelona/Projects/Condcision/Group_level_analyses/Beh_analyses/EEG_condcision_CJ/base_stats.py in <module>
#       1 import numpy as np
# ----> 2 from ..utils import product_matrix_vector
#       3
#       4
#       5 def fast_wilcoxon(X, y=None, zero_method='wilcox', correction=False,
#
# ImportError: attempted relative import with no known parent package

# %%
import base_stats

# %%
base_stats.cor

# %%
corr_linear_circular
# Out:
# <function base_stats.corr_linear_circular(X, alpha)>

# %%
from helper_funs import corr_linear_circular
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_4877/2352819651.py in <module>
# ----> 1 from helper_funs import corr_linear_circular
#
# ImportError: cannot import name 'corr_linear_circular' from 'helper_funs' (/Users/alex/Library/CloudStorage/OneDrive-UniversitatdeBarcelona/Projects/Condcision/Group_level_analyses/Beh_analyses/EEG_condcision_CJ/helper_funs.py)

# %%
y = np.rad2deg(ori_data['X'])

# %%
X = ori_data['Y']

# %%
np.shape(X)
# Out:
# (273, 211, 760)

# %%
corr_linear_circular
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/4m/3h_3fwxd7v33qzl6mfvbj3tr0000gn/T/ipykernel_4877/612042676.py in <module>
# ----> 1 corr_linear_circular
#
# NameError: name 'corr_linear_circular' is not defined

# %%
# define the regressor: here the probe angle
y = np.array(events['probe_circAngle'].values)
X = epochs._data

# We need a 2D X (trials x dimension)
n_trial, n_chan, n_time = epochs._data.shape
X = X.reshape([-1, n_chan * n_time])

# linear circular correlation between MEG and stim angle
_, R2, _ = corr_linear_circular(X, y)

# plot the effect size using MNE
R2 = R2.reshape([n_chan, n_time])
evoked.data = R2
evoked.plot_joint()

# %%
np.shape(ori_data['Y'])
# Out:
# (273, 211, 760)
